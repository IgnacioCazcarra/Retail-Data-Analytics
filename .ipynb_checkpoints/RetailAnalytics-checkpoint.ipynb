# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
features = pd.read_csv('features.csv')
sales = pd.read_csv('sales.csv')
stores = pd.read_csv('stores.csv')

# %% [markdown]
# ## 1- Merge some useful features into the dataset

# %%
sales['Year'] = pd.to_datetime(sales['Date'], format='%d/%m/%Y').dt.year

sales['n_of_Week'] = pd.to_datetime(sales['Date'], format='%d/%m/%Y').dt.week

sales.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Year  n_of_Week
# 0      1     1  05/02/2010      24924.50      False  2010          5
# 1      1     1  12/02/2010      46039.49       True  2010          6
# 2      1     1  19/02/2010      41595.55      False  2010          7
# 3      1     1  26/02/2010      19403.54      False  2010          8
# 4      1     1  05/03/2010      21827.90      False  2010          9

# %% [markdown]
# #### Stores dataset

# %%
#Size and type of store can be useful for predicting the number of sales, so we might as well merge them in to the dataset
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
sales = pd.merge(sales,stores[['Store','Type','Size']])

# %% [markdown]
# #### Features dataset

# %%
features.tail()
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday
# 8185       3.00    2449.97    3169.69  NaN           NaN      False
# 8186     582.74    5797.47    1514.93  NaN           NaN      False
# 8187      85.72     744.84    2150.36  NaN           NaN      False
# 8188     204.19     363.00    1059.46  NaN           NaN      False
# 8189       2.06      10.88    1864.57  NaN           NaN      False

# %%
sales = pd.merge(sales, features[['Store','Date','Unemployment','Fuel_Price','Temperature','CPI']])

sales.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Year  n_of_Week Type  \
# 0      1     1  05/02/2010      24924.50      False  2010          5    A
# 1      1     2  05/02/2010      50605.27      False  2010          5    A
# 2      1     3  05/02/2010      13740.12      False  2010          5    A
# 3      1     4  05/02/2010      39954.04      False  2010          5    A
# 4      1     5  05/02/2010      32229.38      False  2010          5    A
#
#      Size  Unemployment  Fuel_Price  Temperature         CPI
# 0  151315         8.106       2.572        42.31  211.096358
# 1  151315         8.106       2.572        42.31  211.096358
# 2  151315         8.106       2.572        42.31  211.096358
# 3  151315         8.106       2.572        42.31  211.096358
# 4  151315         8.106       2.572        42.31  211.096358

# %% [markdown]
# ## 2- Plot weekly sales for each year

# %%
year_list = []

for year in sales['Year'].unique():
    sales_per_year = sales[sales['Year']==year]['Weekly_Sales'].groupby(sales['n_of_Week']).sum().reset_index()
    year_list.append(sales_per_year)

# %%
plt.figure(figsize=(14,7))

colors = ['blue','green','orange']

for i in range(len(year_list)):
    sns.lineplot(x = 'n_of_Week', y = 'Weekly_Sales', data = year_list[i], color = colors[i])

plt.title('Sales per year', fontsize=20)
plt.grid()
plt.xticks(np.arange(1,53,1))

holiday = sales['n_of_Week'].values[(sales['IsHoliday'])]
for holiday_week in holiday:
    plt.axvline(holiday_week, color='red',linestyle='--')

labels = [year for year in sales['Year'].unique()]
labels.append('Holiday')

plt.legend(labels = labels)
plt.show()

# %% [markdown]
# ## 3- Predict the department-wide sales for each store for the following year

# %% [markdown]
# ### A) Insert 2013 registers into the 'predictions_2013' dataset

# %%
new_departments = sales['Dept'].unique()
new_stores = np.arange(1,45,1) #There are 45 stores
holiday_list = [6,36,47,52] #With the graph above we can see when are the holidays

# %%
from datetime import datetime as dtime, date as d_date
def get2013Dates():
    year = 2013
    dates = []
    for week in range(1,53):
        date = "{}-{}-1".format(year, week)
        dt = dtime.strptime(date, "%Y-%W-%w")
        dates.append(dt.strftime("%d/%m/%Y"))
    return dates

new_dates = get2013Dates()

# %%
#Generate Data for 2013

predictions_2013 = pd.DataFrame(columns=['Store','Dept','n_of_Week','IsHoliday'])

for store in new_stores:
    for dept in new_departments:
        for current_date in new_dates:
            
            d,m,y = current_date.split('/')
            
            nweek = d_date(day = int(d), month = int(m), year = int(y)).isocalendar()[1]
            
            if(nweek in holiday_list):
                holiday_to_insert = True
            else:
                holiday_to_insert = False
                
            row = {'Store':store,'Dept':dept,'n_of_Week':nweek,'IsHoliday':holiday_to_insert}
            predictions_2013 = predictions_2013.append(row, ignore_index=True)

# %% [markdown]
# ### B) Save the dataset to avoid executing the code everytime

# %%
#We will use this dataset once our model is trained and ready to predict with a decent percentage of accuracy
predictions_2013.to_csv('predictions_2013.csv')

# %% [markdown]
# ### C) Split dataset into train and test

# %%
from sklearn.model_selection import train_test_split

y = sales['Weekly_Sales']
#We dont need the year so we drop it
x = sales.drop(['Year','n_of_Week','Weekly_Sales'], axis=1)

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3)

# %%
import tensorflow as tf

# %%
x.head()
# Out:
#    Store  Dept        Date  IsHoliday Type    Size  Unemployment  Fuel_Price  \
# 0      1     1  05/02/2010      False    A  151315         8.106       2.572
# 1      1     2  05/02/2010      False    A  151315         8.106       2.572
# 2      1     3  05/02/2010      False    A  151315         8.106       2.572
# 3      1     4  05/02/2010      False    A  151315         8.106       2.572
# 4      1     5  05/02/2010      False    A  151315         8.106       2.572
#
#    Temperature         CPI
# 0        42.31  211.096358
# 1        42.31  211.096358
# 2        42.31  211.096358
# 3        42.31  211.096358
# 4        42.31  211.096358
